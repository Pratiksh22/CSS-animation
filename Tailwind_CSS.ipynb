# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratiksh22/CSS-animation/blob/main/Tailwind_CSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Q.1 User Login page**

# %%
<!DOCTYPE html>
<html>
<head>
    <meta charset="UTF-8" />
    <title>User Login Page</title>
      <script src="https://cdn.tailwindcss.com"></script>
</head>
<body class="bg-white flex items-center justify-center min-h-screen px-4">
   <div class="w-full max-w-5xl flex flex-col md:flex-row items-center bg-white shadow-md rounded-lg overflow-hidden">

    <!-- Left: Login Form -->
    <div class="w-full md:w-1/2 p-8">
      <h2 class="text-2xl font-semibold mb-2 text-center">Login</h2>
      <p class="text-gray-600 text-sm mb-6 text-center">Enter your credentials to access your account</p>

      <!-- Google Login -->
      <button class="w-full border border-gray-300 text-sm py-2 flex items-center justify-center rounded-md hover:bg-gray-100 mb-4">
        <img src="https://www.svgrepo.com/show/475656/google-color.svg" alt="Google" class="w-5 h-5 mr-2">
        Login with Google
      </button>

      <!-- Divider -->
      <div class="flex items-center mb-4">
        <div class="flex-grow h-px bg-gray-300"></div>
        <span class="text-gray-400 px-2 text-sm">OR</span>
        <div class="flex-grow h-px bg-gray-300"></div>
      </div>

      <!-- Email -->
      <div class="mb-4">
        <label class="block text-sm font-medium text-gray-700 mb-1">Email Address</label>
        <input type="email" class="w-full border border-gray-300 rounded-md px-3 py-2 text-sm focus:outline-none focus:ring-2 focus:ring-blue-400" placeholder="Enter email">
      </div>

      <!-- Password -->
      <div class="mb-2 flex justify-between items-center">
        <label class="block text-sm font-medium text-gray-700">Password</label>
        <a href="#" class="text-sm text-blue-500 hover:underline">Forgot Password?</a>
      </div>
      <input type="password" class="w-full border border-gray-300 rounded-md px-3 py-2 text-sm mb-4 focus:outline-none focus:ring-2 focus:ring-blue-400" placeholder="Enter password">

      <!-- Login Button -->
      <button class="w-full bg-blue-500 hover:bg-blue-600 text-white py-2 rounded-md text-sm font-semibold">Login</button>

      <!-- Register -->
      <p class="text-sm text-center text-gray-600 mt-4">
        Don’t have an account? <a href="#" class="text-blue-500 hover:underline">Register here!</a>
      </p>
    </div>

    <!-- Right: Image (hidden on small screens) -->
    <div class="hidden md:block md:w-1/2 p-4">
      <img src="short-hair-girl-posing-red-tshirt.jpg" alt="Illustration" class="object-cover h-full w-full">
    </div>

  </div>
</body>
</html>

# %% [markdown]
# Output;
# ![Screenshot (33).png](data:image/png;base64,...)![Screenshot (34).png](data:image/png;base64,...)

# %% [markdown]
# **Q 2 Image gallery**

# %%
<!DOCTYPE html>
<html>
<head>
    <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Image Gallery</title>
 <script src="https://cdn.tailwindcss.com"></script>
</head>
<body class="bg-gray-50 min-h-screen flex flex-col items-center p-6">


  <!-- Responsive Gallery Grid -->
  <div class="grid grid-cols-1 sm:grid-cols-2 md:grid-cols-3 lg:grid-cols-4 gap-6 w-full max-w-6xl">
    <!-- Image Card -->
    <div class="overflow-hidden rounded-lg shadow-md hover:shadow-xl transition-shadow duration-300 bg-white">
      <img src="short-hair-girl-posing-red-tshirt.jpg" alt="Sponsor 1" class="w-full h-auto object-cover">
    </div>

    <div class="overflow-hidden rounded-lg shadow-md hover:shadow-xl transition-shadow duration-300 bg-white">
      <img src="short-hair-girl-posing-red-tshirt.jpg" alt="Sponsor 2" class="w-full h-auto object-cover">
    </div>

    <div class="overflow-hidden rounded-lg shadow-md hover:shadow-xl transition-shadow duration-300 bg-white">
      <img src="short-hair-girl-posing-red-tshirt.jpg" alt="Sponsor 3" class="w-full h-auto object-cover">
    </div>

    <div class="overflow-hidden rounded-lg shadow-md hover:shadow-xl transition-shadow duration-300 bg-white">
      <img src="short-hair-girl-posing-red-tshirt.jpg" alt="Sponsor 4" class="w-full h-auto object-cover">
    </div>

    <!-- Add more cards as needed -->
    <div class="overflow-hidden rounded-lg shadow-md hover:shadow-xl transition-shadow duration-300 bg-white">
      <img src="short-hair-girl-posing-red-tshirt.jpg" alt="Sponsor 5" class="w-full h-auto object-cover">
    </div>

    <div class="overflow-hidden rounded-lg shadow-md hover:shadow-xl transition-shadow duration-300 bg-white">
      <img src="short-hair-girl-posing-red-tshirt.jpg" alt="Sponsor 6" class="w-full h-auto object-cover">
    </div>
  </div>

</body>
</html>

# %% [markdown]
# ![Screenshot (32).png](data:image/png;base64,...)![Screenshot (31).png](data:image/png;base64,...)![Screenshot (30).png](data:image/png;base64,...)

# %% [markdown]
# **Q.3  Dashboard**

# %%
<!DOCTYPE html>
<html lang="en" data-theme="light">
<head>
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1.0" />
  <title>Non-Responsive Dashboard</title>
  <script src="https://cdn.tailwindcss.com"></script>
  <script>
    tailwind.config = {
      plugins: [window.daisyui],
    }
  </script>
  <script src="https://cdn.jsdelivr.net/npm/daisyui@3.1.5/dist/full.js"></script>
  <link href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free/css/all.css" rel="stylesheet">
</head>

<body class="bg-gray-100 text-gray-800 font-sans">

  <div class="flex h-screen overflow-hidden">

    <!-- Sidebar -->
    <aside class="w-64 bg-white shadow-md border-r h-full">
      <div class="p-6 text-2xl font-bold border-b">My Dashboard</div>
      <nav class="p-4 space-y-4 text-sm">
        <a class="flex items-center gap-3 text-gray-700 hover:text-blue-600">
          <i class="fas fa-home"></i> Dashboard
        </a>
        <a class="flex items-center gap-3 text-gray-700 hover:text-blue-600">
          <i class="fas fa-chart-line"></i> Analytics
        </a>
        <a class="flex items-center gap-3 text-gray-700 hover:text-blue-600">
          <i class="fas fa-users"></i> Users
        </a>
        <a class="flex items-center gap-3 text-gray-700 hover:text-blue-600">
          <i class="fas fa-cog"></i> Settings
        </a>
        <a class="flex items-center gap-3 text-gray-700 hover:text-blue-600">
          <i class="fas fa-sign-out-alt"></i> Logout
        </a>
      </nav>
    </aside>

    <!-- Main Content -->
    <div class="flex-1 flex flex-col">

      <!-- Top Navbar -->
      <header class="bg-white shadow-md px-6 py-4 flex justify-between items-center border-b">
        <h1 class="text-xl font-semibold">Welcome back, Admin!</h1>
        <div class="flex items-center space-x-4">
          <input type="text" placeholder="Search..." class="input input-bordered input-sm w-48" />
          <div class="avatar">
            <div class="w-8 rounded-full">
              <img src="https://i.pravatar.cc/100?img=1" />
            </div>
          </div>
        </div>
      </header>

      <!-- Main Content Area -->
      <main class="p-6 space-y-6 overflow-y-auto">
        <section class="grid grid-cols-3 gap-4">
          <div class="bg-white p-4 shadow rounded-lg">
            <h2 class="text-lg font-medium mb-2">Total Users</h2>
            <p class="text-2xl font-bold text-blue-600">1,245</p>
          </div>
          <div class="bg-white p-4 shadow rounded-lg">
            <h2 class="text-lg font-medium mb-2">Active Sessions</h2>
            <p class="text-2xl font-bold text-green-600">312</p>
          </div>
          <div class="bg-white p-4 shadow rounded-lg">
            <h2 class="text-lg font-medium mb-2">Errors</h2>
            <p class="text-2xl font-bold text-red-600">12</p>
          </div>
        </section>

        <section class="bg-white p-6 shadow rounded-lg">
          <h2 class="text-xl font-semibold mb-4">Recent Activity</h2>
          <ul class="space-y-2 text-sm">
            <li>✅ User <strong>John</strong> created a report</li>
            <li>✅ New user <strong>Sara</strong> signed up</li>
            <li>❌ Failed login attempt from IP 192.168.1.2</li>
          </ul>
        </section>
      </main>
    </div>
  </div>

</body>
</html>

# %% [markdown]
# ![Screenshot (35).png](data:image/png;base64,...)
